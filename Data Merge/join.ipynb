# %%
import pandas as pd

# %%
shopee = pd.read_csv('D:\Dev\Tetris\Data Merge\Shopee.csv')
tokped = pd.read_csv('D:\Dev\Tetris\Data Merge\Tokopedia.csv')
bukalapak = pd.read_csv('D:\Dev\Tetris\Data Merge\Bukalapak.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:3: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:3: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\MasAm\AppData\Local\Temp\ipykernel_10968\2796761891.py:1: SyntaxWarning: invalid escape sequence '\D'
#   shopee = pd.read_csv('D:\Dev\Tetris\Data Merge\Shopee.csv')
# C:\Users\MasAm\AppData\Local\Temp\ipykernel_10968\2796761891.py:2: SyntaxWarning: invalid escape sequence '\D'
#   tokped = pd.read_csv('D:\Dev\Tetris\Data Merge\Tokopedia.csv')
# C:\Users\MasAm\AppData\Local\Temp\ipykernel_10968\2796761891.py:3: SyntaxWarning: invalid escape sequence '\D'
#   bukalapak = pd.read_csv('D:\Dev\Tetris\Data Merge\Bukalapak.csv')

# %%
frames = [shopee, tokped, bukalapak]

result = pd.concat(frames)

# %%
result
# Out:
#               Invoice                     Product Name Product Category  \
# 0      20010153Y8CW66  Tas Sekolah tahan air 15.6 inch      Accessories
# 1      20010176X0XX76             Payung lipat 42 inch      Accessories
# 2      20010176X0XX76    Baju Koko lengan pendek hitam          Pakaian
# 3      20010187I5JB87    Pashmina ceruty premium basic          Pakaian
# 4      20010190D4VD66      Baju Gamis bahan katun gold          Pakaian
# ...               ...                              ...              ...
# 11995    227232532213      Baju Gamis bahan katun gold          Pakaian
# 11996    218331271950    Baju Koko lengan pendek hitam          Pakaian
# 11997    216861013773    Baju Koko lengan pendek hitam          Pakaian
# 11998    204602917293    Baju Koko lengan pendek hitam          Pakaian
# 11999    202433461262    Baju Koko lengan pendek hitam          Pakaian
#
#        Product Price (IDR)  Product Quantity  Shipping Fee (IDR)  \
# ...

# %%
result.to_csv('DATA.csv', index=False)
